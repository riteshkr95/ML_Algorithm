# %% [markdown]
# ## Supervised Machine Learning
# * Supervised Machine Learning : It is association between input and ouput data .
#
# * (A) Classification : A classification , classifies data into a grouup.
# - it is based on categorical data.
# - Logistic Regression
# - Support Vector Machine (SVM)
# - K -Nearest Neighbbors (K-NN)
# - Naive Bays
# - Decision Trees
# - Random forest
# - Grandient Boosting
# - Neural Network
# * (B) Regression : Regression algorithm predicts Numericals Data .
# - Linear Regression
# - Ridge Regression
# - Lasso Regression
# - Support Vector Regression
# - Decision Trees Regression
# - Random Forest Regression
# - Grandient Boosting Regression
# - Neural Network Regression

# %% [markdown]
# # Logistic Regression :

# %% [markdown]
# - It is based on Binary Classification
# - It is a statisticals methods that is used for predicting probability of Target variable .
# - Logistic Regression makes probability  for classification problems that are Discrete in nature.
#                                        - Heart Attack prediction
#                                        - Tumour Prediction
#                                        - Credit card Fraud
#                                        - Spam Detecion

# %%
from PIL import Image

# %%
image =Image.open(r"C:\Users\rites\Downloads\\Sigmoid.jpg")
# C:\Users\rites\Downloads
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x667>

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()
import warnings 
warnings.filterwarnings("ignore")

# %%
# Simple Logistic Regression

# %%
df=pd.read_excel("C:\\Users\\rites\\OneDrive\\desktop\\Data_Science\\Datasets\\Insurance.xlsx")

# %%
df
# Out:
#    Age Bought Premium
# 0   25             no
# 1   30            yes
# 2   35            yes
# 3   40            yes
# 4   45             no
# 5   50            yes

# %%
df["Bought Premium"].replace({"yes" :"1" ,"no" : "0"} ,inplace=True)

# %%
df
# Out:
#    Age Bought Premium
# 0   25              2
# 1   30              1
# 2   35              1
# 3   40              1
# 4   45              2
# 5   50              1

# %%
sns.scatterplot(data=df ,x="Age" , y="Bought Premium")
# Out:
# <Axes: xlabel='Age', ylabel='Bought Premium'>

# %%
# Separate the independent variable and dependent variable .

# %%
X=df[["Age"]]
y=df["Bought Premium"]

# %%
X
# Out:
#    Age
# 0   25
# 1   30
# 2   35
# 3   40
# 4   45
# 5   50

# %%
y
# Out:
# 0    2
# 1    1
# 2    1
# 3    1
# 4    2
# 5    1
# Name: Bought Premium, dtype: object

# %%
# Training the Model

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , y_train , y_test=train_test_split(X ,y,test_size=0.2)

# %%
# model

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model
# Out:
# LogisticRegression()

# %%
model.fit(X_train ,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(X_test)

# %%
y_pred
# Out:
# array(['1', '2'], dtype=object)

# %%
model.predict([[20]])
# Out:
# array(['2'], dtype=object)

# %%
from sklearn import datasets

# %%
digits=datasets.load_digits()

# %%
digits
# Out:
# {'data': array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#         [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#         [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#         ...,
#         [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#         [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#         [ 0.,  0., 10., ..., 12.,  1.,  0.]]),
#  'target': array([0, 1, 2, ..., 8, 9, 8]),
#  'frame': None,
#  'feature_names': ['pixel_0_0',
#   'pixel_0_1',
#   'pixel_0_2',
#   'pixel_0_3',
#   'pixel_0_4',
#   'pixel_0_5',
#   'pixel_0_6',
#   'pixel_0_7',
#   'pixel_1_0',
#   'pixel_1_1',
#   'pixel_1_2',
#   'pixel_1_3',
#   'pixel_1_4',
#   'pixel_1_5',
#   'pixel_1_6',
#   'pixel_1_7',
#   'pixel_2_0',
#   'pixel_2_1',
#   'pixel_2_2',
#   'pixel_2_3',
#   'pixel_2_4',
#   'pixel_2_5',
#   'pixel_2_6',
#   'pixel_2_7',
#   'pixel_3_0',
#   'pixel_3_1',
#   'pixel_3_2',
#   'pixel_3_3',
#   'pixel_3_4',
#   'pixel_3_5',
#   'pixel_3_6',
#   'pixel_3_7',
#   'pixel_4_0',
#   'pixel_4_1',
#   'pixel_4_2',
#   'pixel_4_3',
# ...

# %%
X=digits.data
y=digits.target

# %%
X.shape
# Out:
# (1797, 64)

# %%
y.shape
# Out:
# (1797,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train ,X_test ,y_train ,y_test=train_test_split(X,y,test_size=0.2)

# %%
X_train.shape
# Out:
# (1437, 64)

# %%
y_train.shape
# Out:
# (1437,)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model
# Out:
# LogisticRegression()

# %%
model.fit(X_train ,y_train)
# Out:
# C:\Users\rites\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=model.predict(X_test)

# %%
y_pred
# Out:
# array([9, 7, 8, 2, 2, 8, 9, 5, 4, 3, 6, 9, 8, 2, 9, 4, 0, 2, 6, 7, 6, 2,
#        6, 7, 7, 2, 5, 7, 1, 2, 3, 9, 7, 3, 4, 2, 2, 1, 3, 0, 4, 3, 7, 7,
#        8, 1, 5, 1, 8, 4, 8, 5, 6, 4, 2, 5, 3, 6, 6, 9, 2, 6, 2, 9, 2, 7,
#        0, 0, 2, 3, 5, 0, 8, 1, 7, 7, 1, 8, 8, 2, 2, 6, 2, 0, 0, 9, 1, 8,
#        3, 1, 0, 6, 2, 9, 7, 1, 0, 3, 2, 7, 5, 0, 3, 3, 5, 2, 4, 4, 8, 7,
#        5, 6, 8, 6, 0, 1, 9, 2, 3, 5, 6, 6, 0, 6, 9, 8, 2, 9, 0, 7, 8, 2,
#        8, 3, 6, 9, 8, 2, 0, 9, 2, 2, 0, 6, 5, 9, 1, 5, 7, 4, 6, 3, 6, 1,
#        3, 5, 1, 3, 3, 5, 4, 0, 4, 8, 0, 1, 6, 1, 2, 3, 0, 5, 7, 5, 8, 7,
#        1, 0, 9, 1, 1, 1, 6, 8, 9, 5, 5, 3, 3, 3, 4, 3, 5, 5, 9, 1, 6, 1,
#        1, 8, 9, 5, 7, 0, 6, 6, 9, 3, 0, 5, 1, 4, 6, 6, 5, 4, 1, 3, 7, 6,
#        2, 8, 8, 1, 4, 6, 1, 8, 7, 3, 8, 4, 2, 3, 0, 0, 1, 4, 1, 3, 1, 6,
#        9, 8, 1, 9, 7, 4, 0, 1, 7, 6, 8, 4, 5, 4, 3, 3, 8, 0, 3, 0, 2, 7,
#        9, 2, 3, 8, 0, 1, 6, 2, 8, 5, 4, 8, 4, 1, 8, 2, 2, 8, 9, 3, 6, 4,
# ...

# %%
from sklearn.metrics import accuracy_score

# %%
score=accuracy_score(y_test ,y_pred)*100

# %%
score
# Out:
# 96.94444444444444

# %% [markdown]
# # Support Vector Machine

# %% [markdown]
# * Support vector machine is used for Classification , Regression and Outlier detection .

# %% [markdown]
# - The main object of this algorithm is to find the optimal hyperplane in N- Dimensional space that can separate the data points with maximum marginal.

# %%
svm=Image.open(r"C:\Users\rites\downloads\SVM.jpg")
svm
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768>

# %% [markdown]
# #### SVM Algorithm

# %%
iris=sns.load_dataset("iris")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris["species"].replace({'setosa':"1", 'versicolor':"2", 'virginica':"3"} , inplace=True)

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2       1
# 1           4.9          3.0           1.4          0.2       1
# 2           4.7          3.2           1.3          0.2       1
# 3           4.6          3.1           1.5          0.2       1
# 4           5.0          3.6           1.4          0.2       1

# %%
plt.subplot(1,2,1)
plt.scatter(data=iris ,x="sepal_length" ,y="sepal_width" ,color="green" )
plt.subplot(1,2,2)
plt.scatter(data=iris ,x="petal_length" ,y="petal_width" ,color="red" )

# %%
sns.lmplot(data=iris ,x="sepal_length" ,y="sepal_width" )

# %%
sns.lmplot(data=iris ,x="petal_length" ,y="petal_width")

# %%
# speration of variables

# %%
X=iris.drop(columns="species")
y=iris.species

# %%
X.shape
# Out:
# (150, 4)

# %%
y.shape
# Out:
# (150,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train ,X_test ,y_train ,y_test=train_test_split(X ,y ,test_size=0.2)

# %%
X_train.shape
# Out:
# (120, 4)

# %%
y_train.shape
# Out:
# (120,)

# %%
# model

# %%
from sklearn.svm import SVC

# %%
model=SVC()

# %%
model
# Out:
# SVC()

# %%
model.fit(X_train ,y_train)
# Out:
# SVC()

# %%
y_pred=model.predict(X_test)

# %%
y_pred
# Out:
# array(['3', '1', '2', '3', '2', '3', '1', '2', '1', '2', '2', '3', '1',
#        '3', '3', '2', '3', '1', '1', '2', '3', '1', '2', '3', '3', '3',
#        '1', '3', '3', '2'], dtype=object)

# %%
model.score(X_test ,y_test)
# Out:
# 0.9666666666666667
